# %%
2+5
# Out:
# 7

# %%
'2'+'5'
# Out:
# '25'

# %%
print('Yigit {} {}'.format('Can','Cakar'))
# Out:
# Yigit Can Cakar

# %%
print('Yigit {0} {1}'.format('Can','Cakar'))
# Out:
# Yigit Can Cakar

# %%
MyList=['one','two','three']
MyList.append('four')

# %%
MyList
# Out:
# ['one', 'two', 'three', 'four']

# %%
MyList.pop(3)
MyList
# Out:
# ['one', 'two', 'three']
